# %%
from skimage.io import imread, imshow, imsave
from skimage import util

# %%
img = imread("images/input_examples/img10bit.jpg")

# %%
imshow(util.invert(img))

# %%
imsave("images/output_examples/copy10bit.jpg",util.invert(img))
